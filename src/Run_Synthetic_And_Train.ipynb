# %%
# !rm -rf output
# !rm -rf ../samples

# %%
# !python3 train.py --cuda -nep 50
# Out:
# 2020-02-18 20:59:06,277 Already preprocessed this configuration. Loading now!
# Doing **critic** update steps (100 steps)
# train.py:111: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   interpolates = torch.tensor(alpha * real_data + ((1 - alpha) * fake_data), requires_grad=True)
# [0/50][100/100][1] Loss_D: -75.785446 Loss_G: 64.007835 Loss_D_real: -86.493645 Loss_D_diff -10.708200
# Doing **critic** update steps (100 steps)
# [1/50][100/100][2] Loss_D: -28.435644 Loss_G: 298.519867 Loss_D_real: 63.874519 Loss_D_diff 92.310165
# Doing **critic** update steps (100 steps)
# [2/50][100/100][3] Loss_D: -4.514774 Loss_G: 76.593765 Loss_D_real: 18.794151 Loss_D_diff 23.308926
# Doing **critic** update steps (100 steps)
# [3/50][100/100][4] Loss_D: -33.922089 Loss_G: 45.175293 Loss_D_real: 129.081207 Loss_D_diff 163.003296
# ...

# %%
import numpy as np
arr = np.concatenate(([1, 2, 3, 4], [5, 6, 7, 8]))
arr = np.array(arr)
np.where(arr < 5)[0]

#arr.where()
# Out:
# array([0, 1, 2, 3])
